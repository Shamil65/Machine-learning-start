# %% [markdown]
# <center>
# <div style="background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%);
#             padding: 12px 35px;
#             border-radius: 12px;
#             box-shadow: 0 4px 15px rgba(79, 172, 254, 0.25);
#             margin: 15px 0;
#             display: inline-block;">
#     <h1 style="color: white;
#                font-family: 'Segoe UI', Arial, sans-serif;
#                font-size: 30px;
#                font-weight: 600;
#                margin: 0;
#                letter-spacing: 0.5px;">
#         🧠 Глава 3: Сложная SVM (Dual + Ядра)
#     </h1>
#     <p style="color: rgba(255,255,255,0.85);
#               font-size: 15px;
#               margin: 5px 0 0 0;
#               font-style: italic;
#               font-weight: 300;">
#         Множители Лагранжа α, Kernel Trick и нелинейные границы
#     </p>
# </div>
# </center>
