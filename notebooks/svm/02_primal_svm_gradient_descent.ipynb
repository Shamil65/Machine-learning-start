# %% [markdown]
# <center>
# <div style="background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%);
#             padding: 20px 40px;
#             border-radius: 20px;
#             box-shadow: 0 10px 30px rgba(245, 87, 108, 0.3);
#             margin: 20px 0;">
#     <h1 style="color: white;
#                font-family: 'Segoe UI', Arial, sans-serif;
#                font-size: 38px;
#                font-weight: 700;
#                margin: 0;">
#         ⚙️ Глава 2: Простая SVM (Primal)
#     </h1>
#     <p style="color: rgba(255,255,255,0.9);
#               font-size: 18px;
#               margin: 10px 0 0 0;
#               font-style: italic;">
#         Градиентный спуск, Hinge Loss и разделяющая линия
#     </p>
# </div>
# </center>
