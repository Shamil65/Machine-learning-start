# %% [markdown]
# <center>
# <h1 style="color: #667eea; font-size: 32px; border-bottom: 4px solid #667eea; padding-bottom: 8px; display: inline-block;">
# 🎯 Глава 1: Данные для SVM
# </h1>
# </center>
