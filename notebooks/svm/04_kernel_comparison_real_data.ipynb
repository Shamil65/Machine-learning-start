# %% [markdown]
# <center>
# <div style="background: linear-gradient(135deg, #43e97b 0%, #38f9d7 100%);
#             padding: 12px 35px;
#             border-radius: 12px;
#             box-shadow: 0 4px 15px rgba(67, 233, 123, 0.25);
#             margin: 15px 0;
#             display: inline-block;">
#     <h1 style="color: #1a1a2e;
#                font-family: 'Segoe UI', Arial, sans-serif;
#                font-size: 30px;
#                font-weight: 600;
#                margin: 0;
#                letter-spacing: 0.5px;">
#         🏆 Глава 4: Ядра на реальных данных
#     </h1>
#     <p style="color: rgba(26, 26, 46, 0.75);
#               font-size: 15px;
#               margin: 5px 0 0 0;
#               font-style: italic;
#               font-weight: 300;">
#         Сравнение Linear, Polynomial, RBF на датасете Wine
#     </p>
# </div>
# </center>
