# %%
from sklearn.datasets import load_iris
data = load_iris()

# %%
feature_names = data.keys()   # или data.feature_names
feature_names
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
X = data.data
y = data.target
X.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %%
data.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
data.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %% [markdown]
# Я хочу на графике показать все эти цветки
