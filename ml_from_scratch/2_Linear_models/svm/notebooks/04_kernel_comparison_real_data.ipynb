# %% [markdown]
# <center>
# <div style="background: linear-gradient(135deg, #0f0c29 0%, #302b63 50%, #24243e 100%);
#             padding: 12px 40px;
#             border-radius: 8px;
#             border-left: 4px solid #d2a8ff;
#             box-shadow: 0 4px 20px rgba(210, 168, 255, 0.15);
#             margin: 15px 0;
#             width: 100%;
#             box-sizing: border-box;">
#     <h1 style="color: #d2a8ff;
#                font-family: 'Consolas', 'Courier New', monospace;
#                font-size: 28px;
#                font-weight: 700;
#                margin: 0;
#                letter-spacing: 1px;
#                text-shadow: 0 0 20px rgba(210, 168, 255, 0.3);
#                text-align: center;">
#         🏆 KERNEL_COMPARISON
#     </h1>
#     <p style="color: rgba(255,255,255,0.6);
#               font-size: 13px;
#               margin: 4px 0 0 0;
#               font-family: 'Consolas', 'Courier New', monospace;
#               letter-spacing: 0.5px;
#               text-align: center;">
#         linear · polynomial · rbf · wine_dataset
#     </p>
# </div>
# </center>
