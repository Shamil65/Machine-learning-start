# %%
from sklearn.datasets import load_iris
import pandas as pd
X, y = load_iris(return_X_y=True, as_frame=True)

# %%
print("X.shape: ", X.shape)
print("y.shape: ", y.shape)
# Out:
# X.shape:  (150, 4)
# y.shape:  (150,)

# %%
import sys

path = r'C:\Users\ZiganshinShamil\Desktop\Study\ml_study'
if path not in sys.path:
    sys.path.append(path)

from ml_from_scratch.utils import data_processing
import importlib
importlib.reload(data_processing)

X_train, y_train, X_test, y_test = data_processing._train_test_split(X, y, as_frame=True)

# %%
import sys

path = r'C:\Users\ZiganshinShamil\Desktop\Study\ml_study'
if path not in sys.path:
    sys.path.append(path)

from ml_from_scratch.fixed_log_reg import MyLogReg

verbose = 10000
mylog = MyLogReg(n_iter=100000, learning_rate=0.001, )
mylog.fit(X_train, y_train, verbose=verbose)
# Out:
# start | loss: -2.88
# 10000 | loss: -1.44
# 20000 | loss: -1.44
# 30000 | loss: -1.44
# 40000 | loss: -1.44
# 50000 | loss: -1.44
# 60000 | loss: -1.44
# 70000 | loss: -1.44
# 80000 | loss: -1.44
# 90000 | loss: -1.44
# 100000 | loss: -1.44
