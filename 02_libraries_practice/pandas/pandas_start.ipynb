# %%
import pandas as pd

df = pd.DataFrame({
    "Shamil": [21],
    "Kamil": [20],
    "Aidar": [19]
})
df
# Out:
#    Shamil  Kamil  Aidar
# 0      21     20     19

# %%
ds = pd.Series([1, 2, 3])
ds
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
ds_copy = ds.copy()
ds_copy
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# #### Добавление нового столбца
# X.insert(loc, column, value)

# %%
df.insert(1, "alnert4", [2])
df
# Out:
#    alnert  alnert4  alnert2  Shamil  Kamil  Aidar
# 0       1        2        1      21     20     19

# %%
df = pd.DataFrame({
    "Shamil": [21, 177],
    "Kamil": [20, 177],
    "Aidar": [19, 196]
})
df
# Out:
#    Shamil  Kamil  Aidar
# 0      21     20     19
# 1     177    177    196

# %%
df.insert(0, "albert", [1, 2])

# %%
df
# Out:
#    albert  Shamil  Kamil  Aidar
# 0       1      21     20     19
# 1       2     177    177    196

# %% [markdown]
# #### Вытаскиваем данные из pd в формате np.array

# %%
X_mat = df.values
X_mat
# Out:
# array([[  1,  21,  20,  19],
#        [  2, 177, 177, 196]])

# %% [markdown]
# #### Размеры dataframe

# %%
X_mat.shape
# Out:
# (2, 4)

# %% [markdown]
# #### Из numpy массива в DataFrame

# %%
from sklearn.datasets import load_iris
import pandas as pd
data = load_iris()

feature_names = data.keys()   # или data.feature_names
X = data.data
y = data.target

X = data.data
y = data.target
df_X = pd.DataFrame(X, columns=['sepal length (cm)',
 'sepal width (cm)',
 'petal length (cm)',
 'petal width (cm)'])
df_y = pd.Series(y)
