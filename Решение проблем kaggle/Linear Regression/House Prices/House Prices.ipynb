# %% [markdown]
# # 🏠 House Prices - Advanced Regression Techniques
# https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data
#
#
# ## 📁 Описание файлов
# | Файл | Описание |
# |------|-------------|
# | `train.csv` | Тренировочный набор данных |
# | `test.csv` | Тестовый набор данных (без целевой переменной) |
# | `data_description.txt` | Полное описание колонок (оригинал от Dean De Cock) |
# | `sample_submission.csv` | Пример сабмита (бенчмарк на линейной регрессии) |
#
# ---
#
# ## 🎯 Целевая переменная
# | Переменная | Описание |
# |------------|----------|
# | **SalePrice** | 💰 Цена продажи недвижимости в долларах *(целевая переменная, которую нужно предсказать)* |
#
# ---
#
# ## 📊 Поля данных
#
# ### 🏗 Характеристики здания
# | Поле | Описание |
# |------|----------|
# | `MSSubClass` | Класс здания |
# | `MSZoning` | Общая зональная классификация |
# | `BldgType` | Тип жилого строения |
# | `HouseStyle` | Стиль дома |
# | `OverallQual` | Оценка качества материалов и отделки (1-10) |
# | `OverallCond` | Общая оценка состояния (1-10) |
# | `YearBuilt` | Год постройки |
# | `YearRemodAdd` | Год последней реконструкции |
# | `RoofStyle` | Тип крыши |
# | `RoofMatl` | Материал крыши |
# | `Exterior1st` | Внешняя отделка (основной материал) |
# | `Exterior2nd` | Внешняя отделка (дополнительный материал) |
# | `MasVnrType` | Тип каменной облицовки |
# | `MasVnrArea` | Площадь каменной облицовки (кв. футы) |
# | `ExterQual` | Качество внешних материалов |
# | `ExterCond` | Текущее состояние внешних материалов |
# | `Foundation` | Тип фундамента |
#
# ### 📏 Участок и земля
# | Поле | Описание |
# |------|----------|
# | `LotFrontage` | Длина фасада вдоль улицы (линейные футы) |
# | `LotArea` | Общая площадь участка (кв. футы) |
# | `Street` | Тип доступа к дороге |
# | `Alley` | Тип доступа к аллее |
# | `LotShape` | Форма участка |
# | `LandContour` | Рельеф участка |
# | `Utilities` | Доступные коммуникации |
# | `LotConfig` | Конфигурация участка |
# | `LandSlope` | Уклон участка |
#
# ### 📍 Расположение и район
# | Поле | Описание |
# |------|----------|
# | `Neighborhood` | Физическое расположение в черте города Ames |
# | `Condition1` | Близость к главной дороге или ж/д путям |
# | `Condition2` | Вторая близость (если применимо) |
#
# ### 🏠 Подвал
# | Поле | Описание |
# |------|----------|
# | `BsmtQual` | Высота подвала |
# | `BsmtCond` | Общее состояние подвала |
# | `BsmtExposure` | Наличие выхода в сад/на улицу |
# | `BsmtFinType1` | Качество отделки первой зоны подвала |
# | `BsmtFinSF1` | Площадь отделки Type 1 (кв. футы) |
# | `BsmtFinType2` | Качество отделки второй зоны (если есть) |
# | `BsmtFinSF2` | Площадь отделки Type 2 (кв. футы) |
# | `BsmtUnfSF` | Необработанная площадь подвала |
# | `TotalBsmtSF` | **Общая площадь подвала** |
#
# ### 🔥 Отопление, кондиционирование и электрика
# | Поле | Описание |
# |------|----------|
# | `Heating` | Тип отопления |
# | `HeatingQC` | Качество и состояние отопления |
# | `CentralAir` | Центральное кондиционирование (Y/N) |
# | `Electrical` | Тип электрической системы |
#
# ### 📐 Внутренняя площадь
# | Поле | Описание |
# |------|----------|
# | `1stFlrSF` | Площадь первого этажа |
# | `2ndFlrSF` | Площадь второго этажа |
# | `LowQualFinSF` | Площадь низкокачественной отделки (все этажи) |
# | `GrLivArea` | **Жилая площадь над землёй** (кв. футы) |
# | `FullBath` | Полные ванные комнаты над землёй |
# | `HalfBath` | Половинные ванные над землёй |
# | `BsmtFullBath` | Полные ванные в подвале |
# | `BsmtHalfBath` | Половинные ванные в подвале |
# | `Bedroom` | Количество спален над подвалом |
# | `Kitchen` | Количество кухонь |
# | `KitchenQual` | Качество кухни |
# | `TotRmsAbvGrd` | Всего комнат над землёй (без ванных) |
# | `Functional` | Рейтинг функциональности дома |
#
# ### 🔥 Камины и гараж
# | Поле | Описание |
# |------|----------|
# | `Fireplaces` | Количество каминов |
# | `FireplaceQu` | Качество каминов |
# | `GarageType` | Расположение гаража |
# | `GarageYrBlt` | Год постройки гаража |
# | `GarageFinish` | Отделка интерьера гаража |
# | `GarageCars` | Вместимость гаража (в машинах) |
# | `GarageArea` | Площадь гаража (кв. футы) |
# | `GarageQual` | Качество гаража |
# | `GarageCond` | Состояние гаража |
# | `PavedDrive` | Асфальтированный подъезд (Y/N) |
#
# ### 🌳 Внешние элементы
# | Поле | Описание |
# |------|----------|
# | `WoodDeckSF` | Площадь деревянной террасы |
# | `OpenPorchSF` | Площадь открытого крыльца |
# | `EnclosedPorch` | Площадь закрытого крыльца |
# | `3SsnPorch` | Площадь трёхсезонного крыльца |
# | `ScreenPorch` | Площадь крыльца с москитной сеткой |
# | `PoolArea` | Площадь бассейна |
# | `PoolQC` | Качество бассейна |
# | `Fence` | Качество забора |
# | `MiscFeature` | Прочие особенности (не вошедшие в другие категории) |
# | `MiscVal` | Стоимость прочих особенностей ($) |
#
# ### 📅 Информация о продаже
# | Поле | Описание |
# |------|----------|
# | `MoSold` | Месяц продажи |
# | `YrSold` | Год продажи |
# | `SaleType` | Тип сделки |
# | `SaleCondition` | Условия продажи |
#
# ---
#
# > 💡 **Полезный совет:**
# > - Многие поля содержат пропуски (`NaN`) — это нормально (например, `PoolQC` отсутствует у большинства домов).
# > - Категориальные признаки (тип данных `object`) потребуют кодирования перед обучением модели.
# > - Начни с разведочного анализа данных (`df.describe()`, `df.info()`, визуализации распределений).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

train_df = pd.read_csv(r"C:\Users\ZiganshinShamil\Desktop\Study\Machine learning start\Решение проблем kaggle\Linear Regression\House Prices\House Prices dataset\train.csv", delimiter=',')
test_df = pd.read_csv(r"C:\Users\ZiganshinShamil\Desktop\Study\Machine learning start\Решение проблем kaggle\Linear Regression\House Prices\House Prices dataset\test.csv", delimiter=",")

print("Кол-во признаков в train: ", train_df.shape[1])
print("Кол-во строк в train: ", train_df.shape[0], "\n")

train_df.head(3)
# Out:
# Кол-во признаков в train:  81
# Кол-во строк в train:  1460
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
#
# [3 rows x 81 columns]

# %% [markdown]
# #### Обработка данных

# %% [markdown]
# Удалим столбец id, так как он не нужен

# %%
train_df = train_df.drop("Id", axis=1)
train_df.head(3)
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig  ... PoolArea PoolQC Fence MiscFeature  \
# 0         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
# 1         Lvl    AllPub       FR2  ...        0    NaN   NaN         NaN
# 2         Lvl    AllPub    Inside  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       0      2    2008        WD         Normal     208500
# 1       0      5    2007        WD         Normal     181500
# 2       0      9    2008        WD         Normal     223500
#
# [3 rows x 80 columns]

# %% [markdown]
# Посмотрим типы столбцов

# %%
train_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     1460 non-null   int64
#  1   MSZoning       1460 non-null   str
#  2   LotFrontage    1201 non-null   float64
#  3   LotArea        1460 non-null   int64
#  4   Street         1460 non-null   str
#  5   Alley          91 non-null     str
#  6   LotShape       1460 non-null   str
#  7   LandContour    1460 non-null   str
#  8   Utilities      1460 non-null   str
#  9   LotConfig      1460 non-null   str
#  10  LandSlope      1460 non-null   str
#  11  Neighborhood   1460 non-null   str
#  12  Condition1     1460 non-null   str
#  13  Condition2     1460 non-null   str
#  14  BldgType       1460 non-null   str
#  15  HouseStyle     1460 non-null   str
#  16  OverallQual    1460 non-null   int64
#  17  OverallCond    1460 non-null   int64
# ...

# %% [markdown]
# Этот вывод df.info() — это медицинская карта датасета. Он говорит о трех главных вещах: структуре данных, проблемах с пропусками и типах данных, которые нужно исправить

# %%
print(train_df["SalePrice"].describe())
plt.figure(figsize=(9, 8))
sns.histplot(train_df["SalePrice"], color="g", bins=100, kde=True, alpha=0.4);
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# Распределение цен домов
#
# ```python
# sns.histplot(dataset_df['SalePrice'],
#              color='g',
#              bins=100,
#              kde=True,
#              alpha=0.4);
# ```
#
# **Что важно:**
#
# - `histplot` — строит гистограмму (замена `distplot`)
# - `bins=100` — количество столбиков (можно уменьшить до 30–50)
# - `kde=True` — добавляет плавную кривую распределения
# - `alpha=0.4` — прозрачность столбиков
# - `;` — скрывает технический вывод в Jupyter

# %% [markdown]
# Вытащим только числовые данные

# %%
list(set(train_df.dtypes.tolist()))
# Out:
# [<StringDtype(storage='python', na_value=nan)>,
#  dtype('int64'),
#  dtype('float64')]

# %%
train_df.select_dtypes(include=["int64", "float64"])
