# %% [markdown]
# # Анализ набора данных о диабете
#
# ## Описание
# Данные взяты из [sklearn.datasets.load_diabetes](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_diabetes.html).
# Набор содержит **442 наблюдения** за пациентами с сахарным диабетом. Для каждого пациента доступны:
#
# - **10 исходных признаков**:
#   - возраст (`age`)
#   - пол (`sex`)
#   - индекс массы тела (`bmi`)
#   - среднее артериальное давление (`bp`)
#   - шесть показателей сыворотки крови (`s1`–`s6`)
# - **Целевая переменная**:
#   - количественная мера прогрессирования заболевания через год (`target`)
#
# Все признаки были предварительно стандартизированы (центрированы и нормированы).

# %%
from sklearn.datasets import load_diabetes
import pandas as pd
X, y = load_diabetes(return_X_y=True, as_frame=True, scaled=True)
X.head()
# Out:
#     age  sex   bmi     bp     s1     s2    s3   s4      s5    s6
# 0  59.0  2.0  32.1  101.0  157.0   93.2  38.0  4.0  4.8598  87.0
# 1  48.0  1.0  21.6   87.0  183.0  103.2  70.0  3.0  3.8918  69.0
# 2  72.0  2.0  30.5   93.0  156.0   93.6  41.0  4.0  4.6728  85.0
# 3  24.0  1.0  25.3   84.0  198.0  131.4  40.0  5.0  4.8903  89.0
# 4  50.0  1.0  23.0  101.0  192.0  125.4  52.0  4.0  4.2905  80.0

# %%
X= X.dropna()
y = y.loc[X.index]

# %%
from my_line_reg import MyLineReg

model_linear = MyLineReg(n_iter=10000)

model_linear.fit(X, y, verbose = 1000)
print(model_linear)
# Out:
# start | loss: 233497.41070607913
# iter 1000 | loss: nan
# c:\Users\ZiganshinShamil\Desktop\Study\Machine learning start\Решение проблем kaggle\Linear Regression\Diabetes Dataset\my_line_reg.py:84: RuntimeWarning: overflow encountered in matmul
#   gradient = (2 / m) * (X_mat.T @ errors)
# c:\Users\ZiganshinShamil\Desktop\Study\Machine learning start\Решение проблем kaggle\Linear Regression\Diabetes Dataset\my_line_reg.py:115: RuntimeWarning: invalid value encountered in subtract
#   self.weights = self.weights - self.learning_rate_iter * gradient
# iter 2000 | loss: nan
# iter 3000 | loss: nan
# iter 4000 | loss: nan
# iter 5000 | loss: nan
# iter 6000 | loss: nan
# iter 7000 | loss: nan
# iter 8000 | loss: nan
# iter 9000 | loss: nan
# iter 10000 | loss: nan
# MyLineReg class: n_iter=10000, learning_rate=0.001

# %%
X_sample = X.iloc[[0]]

prediction = model_linear.predict(X_sample)
print("Предсказанное значение: ", prediction)
print("Реальное значение: ", y.iloc[0])
# Out:
# Предсказанное значение:  0   NaN
# dtype: float64
# Реальное значение:  151.0
