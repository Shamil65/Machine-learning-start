# %% [markdown]
# # Анализ набора данных о диабете
#
# ## Описание
# Данные взяты из [sklearn.datasets.load_diabetes](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_diabetes.html).
# Набор содержит **442 наблюдения** за пациентами с сахарным диабетом. Для каждого пациента доступны:
#
# - **10 исходных признаков**:
#   - возраст (`age`)
#   - пол (`sex`)
#   - индекс массы тела (`bmi`)
#   - среднее артериальное давление (`bp`)
#   - шесть показателей сыворотки крови (`s1`–`s6`)
# - **Целевая переменная**:
#   - количественная мера прогрессирования заболевания через год (`target`)
#
# Все признаки были предварительно стандартизированы (центрированы и нормированы).

# %%
from sklearn.datasets import load_diabetes
import pandas as pd
X, y = load_diabetes(return_X_y=True, as_frame=True, scaled=True)
X.shape
# Out:
# (442, 10)

# %%
y.shape
# Out:
# (442,)

# %%
print("Диапазоны признаков (мин - макс):")
print(X.describe().loc[['min', 'max']])
# Out:
# Диапазоны признаков (мин - макс):
#       age  sex   bmi     bp     s1     s2    s3    s4      s5     s6
# min  19.0  1.0  18.0   62.0   97.0   41.6  22.0  2.00  3.2581   58.0
# max  79.0  2.0  42.2  133.0  301.0  242.4  99.0  9.09  6.1070  124.0

# %%
import os
import sys

sys.path.append(r"C:\Users\ZiganshinShamil\Desktop\Study\Machine learning start\Решение проблем kaggle\Linear Regression\Diabetes Dataset")

# %%
from my_line_reg import MyLineReg

model_linear = MyLineReg(n_iter=100000, sgd_sample=0.2, learning_rate=0.00001)

model_linear.fit(X, y, verbose = 1000)
print(model_linear)
# Out:
# start | loss: 233497.41070607913
# iter 1000 | loss: 2768.4957560772814
# iter 2000 | loss: 3094.4002037046575
# iter 3000 | loss: 3268.0701878740406
# iter 4000 | loss: 3668.1288615389362
# iter 5000 | loss: 3294.9631270441537
# iter 6000 | loss: 3012.447190559824
# iter 7000 | loss: 2908.9645729261497
# iter 8000 | loss: 3373.2728416317113
# iter 9000 | loss: 3053.3467674211133
# iter 10000 | loss: 3388.6064348405125
# iter 11000 | loss: 3562.834285903011
# iter 12000 | loss: 3899.149626587203
# iter 13000 | loss: 3004.5500366373076
# iter 14000 | loss: 2805.1855839863897
# iter 15000 | loss: 3548.5308198805888
# iter 16000 | loss: 3283.0456116186488
# iter 17000 | loss: 3141.1731137205275
# iter 18000 | loss: 3782.685670652585
# iter 19000 | loss: 2918.846495576923
# iter 20000 | loss: 3666.490490488374
# iter 21000 | loss: 3791.2369529256025
# iter 22000 | loss: 2841.1170485884036
# iter 23000 | loss: 2632.322545151626
# iter 24000 | loss: 4177.710074507671
# iter 25000 | loss: 2950.6462289208116
# iter 26000 | loss: 2961.468482705736
# iter 27000 | loss: 2939.702701060948
# iter 28000 | loss: 3695.7669769764734
# iter 29000 | loss: 3241.175936515407
# iter 30000 | loss: 3359.43717710561
# iter 31000 | loss: 3110.6356115549092
# iter 32000 | loss: 3115.818689997599
# iter 33000 | loss: 2719.6160194873364
# iter 34000 | loss: 3594.6590311087016
# iter 35000 | loss: 3150.5335961765727
# iter 36000 | loss: 3743.6513869918226
